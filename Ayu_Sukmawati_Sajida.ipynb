# %% [markdown]
# <a href="https://colab.research.google.com/github/sukmaayu02/Ayu-Sukmawati-Sajida_TugasMachineLearning/blob/main/Ayu_Sukmawati_Sajida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("/content/drive/MyDrive/Ayu Sukmawati Sajida_TM9/dataset/data.csv")
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
df.shape
# Out:
# (6819, 96)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
df[['Bankrupt?', ' Liability-Assets Flag', ' Net Income Flag']].head(10)
# Out:
#    Bankrupt?   Liability-Assets Flag   Net Income Flag
# 0          1                       0                 1
# 1          1                       0                 1
# 2          1                       0                 1
# 3          1                       0                 1
# 4          1                       0                 1
# 5          1                       0                 1
# 6          0                       0                 1
# 7          0                       0                 1
# 8          0                       0                 1
# 9          0                       0                 1

# %%
df['Bankrupt?'].value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(10,5))
ax = sns.countplot(ax=ax, data=df, x=df['Bankrupt?'])
for container in ax.containers:
    ax.bar_label(container)

# %%
X = df.drop(['Bankrupt?', ' Liability-Assets Flag', ' Net Income Flag'], axis=1)
y = df['Bankrupt?']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=27, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=27, stratify=y_train)

print("X Train shape:",X_train.shape)
print("X Test shape:",X_test.shape)
print("y Train shape:",y_train.shape)
print("y Test shape:",y_test.shape)
print("X Val shape:",X_val.shape)
print("y Val shape:",y_val.shape)
# Out:
# X Train shape: (4364, 93)
# X Test shape: (1364, 93)
# y Train shape: (4364,)
# y Test shape: (1364,)
# X Val shape: (1091, 93)
# y Val shape: (1091,)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
X_res.shape
# Out:
# (8446, 93)

# %%
y_res.value_counts()
# Out:
# Bankrupt?
# 0    4223
# 1    4223
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
def model_report(data, model_name, ytest, ypred):
    dict = {}
    dict['Model'] = model_name
    dict['Accuracy'] = accuracy_score(ytest, ypred)
    dict['F-1'] = f1_score(ytest, ypred)
    dict['Recall'] = recall_score(ytest, ypred)
    dict['Precision'] = precision_score(ytest, ypred)
    return pd.concat([data, pd.DataFrame(dict, index=[0])], ignore_index=True)

# %%
def train_model(trainX, trainY, testX, testY):
    models = pd.DataFrame(columns=['Model', "Accuracy", 'F-1', 'Recall', 'Precision'])

    lr = LogisticRegression()
    lr.fit(trainX, trainY)
    lr_pred = lr.predict(testX)
    models = model_report(models,"Logistic Regression", testY, lr_pred)

    svm = SVC(random_state=42)
    svm.fit(trainX, trainY)
    svm_pred = svm.predict(testX)
    models = model_report(models,"SVM", testY, svm_pred)

    dtc = DecisionTreeClassifier(random_state=42)
    dtc.fit(trainX, trainY)
    dtc_pred = dtc.predict(testX)
    models = model_report(models,"Decision Tree", testY, lr_pred)

    gnb = GaussianNB()
    gnb.fit(trainX, trainY)
    gnb_pred = gnb.predict(testX)
    models = model_report(models,"Naive Bayes", testY, gnb_pred)

    knn = KNeighborsClassifier()
    knn.fit(trainX, trainY)
    knn_pred = knn.predict(testX)
    models = model_report(models,"KNN", testY, knn_pred)

    return models

# %%
baseline = train_model(X_train, y_train, X_test, y_test)
baseline
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.958944  0.000000  0.000000   0.000000
# 1                  SVM  0.967742  0.000000  0.000000   0.000000
# 2        Decision Tree  0.958944  0.000000  0.000000   0.000000
# 3          Naive Bayes  0.079179  0.061286  0.931818   0.031685
# 4                  KNN  0.968475  0.044444  0.022727   1.000000

# %%
baseline = train_model(X_res, y_res, X_test, y_test)
baseline
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.726540  0.079012  0.363636   0.044321
# 1                  SVM  0.779326  0.122449  0.477273   0.070234
# 2        Decision Tree  0.726540  0.079012  0.363636   0.044321
# 3          Naive Bayes  0.082845  0.061515  0.931818   0.031808
# 4                  KNN  0.843109  0.093220  0.250000   0.057292

# %%
class StandardScaler():
    def __init__(self) -> None:
        self.mean = {}
        self.std = {}

    def fit(self,trainX):
        for col in trainX:
            self.mean[col] = (np.mean(trainX[col]))
            self.std[col]= (np.std(trainX[col]))

    def standard_scaler(self,x,col):
        xmean = self.mean[col]
        xstd = self.std[col]
        x_std_scaled = (x - xmean) / xstd
        return x_std_scaled

    def transform(self,trainX):
        result = trainX.copy()
        for col in trainX:
            result[col] = trainX[col].apply(lambda x: self.standard_scaler(x, col))
        return result

# %%
scaler = StandardScaler()
scaler.fit(X_res)
X_train_standard = scaler.transform(X_res)
X_test_standard = scaler.transform(X_test)
X_val_standard = scaler.transform(X_val)

# %%
normalization_sc = train_model(X_train_standard, y_res, X_test_standard, y_test)
normalization_sc
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.896628  0.291457  0.659091   0.187097
# 1                  SVM  0.923021  0.313725  0.545455   0.220183
# 2        Decision Tree  0.896628  0.291457  0.659091   0.187097
# 3          Naive Bayes  0.248534  0.060495  0.750000   0.031519
# 4                  KNN  0.884164  0.233010  0.545455   0.148148

# %%
class MinMaxScale():
    def __init__(self) -> None:
        self.max_val = pd.Series(dtype="float64")
        self.min_val = pd.Series(dtype="float64")

    def fit(self,trainX):
        self.min_val = np.min(trainX, axis=0)
        self.max_val = np.max(trainX, axis=0)

    def minmax_scaler(self,trainX,feature_range=(0, 1)):
        scaled_X = (trainX - self.min_val) / (self.max_val - self.min_val)
        scaled_X = scaled_X * (feature_range[1] - feature_range[0]) + feature_range[0]
        return scaled_X

    def transform(self,trainX,feature_range=(0, 1)):
        result = self.minmax_scaler(trainX,feature_range)
        return result

# %%
scaler = MinMaxScale()
scaler.fit(X_res)
X_train_minmax = scaler.transform(X_res)
X_test_minmax = scaler.transform(X_test)
X_val_minmax = scaler.transform(X_val)

# %%
normalization_mm = train_model(X_train_minmax, y_res, X_test_minmax, y_test)
normalization_mm
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.884164  0.281818  0.704545   0.176136
# 1                  SVM  0.896628  0.298507  0.681818   0.191083
# 2        Decision Tree  0.884164  0.281818  0.704545   0.176136
# 3          Naive Bayes  0.296188  0.064327  0.750000   0.033605
# 4                  KNN  0.889296  0.225641  0.500000   0.145695

# %%
normalization_sc
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.896628  0.291457  0.659091   0.187097
# 1                  SVM  0.923021  0.313725  0.545455   0.220183
# 2        Decision Tree  0.896628  0.291457  0.659091   0.187097
# 3          Naive Bayes  0.248534  0.060495  0.750000   0.031519
# 4                  KNN  0.884164  0.233010  0.545455   0.148148

# %%
normalization_sc
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.896628  0.291457  0.659091   0.187097
# 1                  SVM  0.923021  0.313725  0.545455   0.220183
# 2        Decision Tree  0.896628  0.291457  0.659091   0.187097
# 3          Naive Bayes  0.248534  0.060495  0.750000   0.031519
# 4                  KNN  0.884164  0.233010  0.545455   0.148148

# %%
normalization_mm
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.884164  0.281818  0.704545   0.176136
# 1                  SVM  0.896628  0.298507  0.681818   0.191083
# 2        Decision Tree  0.884164  0.281818  0.704545   0.176136
# 3          Naive Bayes  0.296188  0.064327  0.750000   0.033605
# 4                  KNN  0.889296  0.225641  0.500000   0.145695

# %%
pd.DataFrame({'Standard Scaler': normalization_sc['F-1'].mean(), 'MinMax Scaler': normalization_mm['F-1'].mean()}, index = [0])
# Out:
#    Standard Scaler  MinMax Scaler
# 0         0.238029       0.230422

# %%
def AnovaFeatureSelection (trainX,trainY):
    fscores = []

    temp = np.array(trainX)
    ind0 = trainY == 0
    ind1 = trainY == 1

    for col in temp.T:
        X0 = col[ind0]
        X1 = col[ind1]

        meanall = np.mean(col)
        mean0 = np.mean(X0)
        mean1 = np.mean(X1)

        dbc = (sum(ind0) * (mean0 - meanall)**2) + (sum(ind1) * (mean1 - meanall)**2)
        ssw1 = np.sum((X0 - mean0)**2)
        ssw2 = np.sum((X1 - mean1)**2)
        nt = sum(ind0) + sum(ind1) - 2
        cof = (ssw1 + ssw2)/nt

        fscore = dbc/cof
        fscores.append(fscore)
    return fscores

# %%
def ShowFS(data, target, k):
    score = AnovaFeatureSelection(data, target)

    df = pd.DataFrame({'Features':data.columns, 'Scores':score})
    df.sort_values(by='Scores', ascending=False, inplace = True)
    df = df.iloc[:k,:]
    return df

# %%
def score_per_k (trainX, trainY, validX, validY):
    num_k = []
    scores = []

    for i in range(1, len(trainX.columns)):
        num_k.append(i)
        df = ShowFS(trainX, trainY, i)
        df_train = train_model(trainX[df["Features"]], trainY, validX[df["Features"]], validY)
        scores.append(df_train['F-1'].mean())

    df_k = pd.DataFrame({'K':num_k, 'Mean F1 Scores':scores})
    return df_k

# %%
def select_k (df_k):
    max_f1_score = df_k['Mean F1 Scores'].idxmax()
    k_optimal = df_k.loc[max_f1_score, 'K']
    return k_optimal

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

# Generating synthetic data for the example
np.random.seed(42)
X_res = np.random.rand(100, 5)  # 100 samples, 5 features
y_res = np.random.randint(0, 2, 100)  # Binary target variable
X_val = np.random.rand(30, 5)  # 30 samples, 5 features
y_val = np.random.randint(0, 2, 30)  # Binary target variable

def score_per_k(X_res, y_res, X_val, y_val, max_k=92):
    scores = []
    for k in range(1, max_k + 1):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_res, y_res)
        y_pred = knn.predict(X_val)
        f1 = f1_score(y_val, y_pred, average='macro')
        scores.append((k, f1))

    df_k = pd.DataFrame(scores, columns=['K', 'Mean F1 Scores'])
    return df_k

# Getting the score per k
df_k = score_per_k(X_res, y_res, X_val, y_val)
df_k
# Out:
#      K  Mean F1 Scores
# 0    1        0.682726
# 1    2        0.466484
# 2    3        0.583333
# 3    4        0.499358
# 4    5        0.569378
# ..  ..             ...
# 87  88        0.361702
# 88  89        0.361702
# 89  90        0.361702
# 90  91        0.361702
# 91  92        0.361702
#
# [92 rows x 2 columns]

# %%
k_optimal = select_k (df_k)

print("Banyak fitur optimal untuk diambil:", k_optimal)
# Out:
# Banyak fitur optimal untuk diambil: 1

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif

# Generating synthetic data for the example
np.random.seed(42)
X_res = np.random.rand(100, 93)  # 100 samples, 93 features
y_res = np.random.randint(0, 2, 100)  # Binary target variable

# Assume feature names are given as follows (for example purposes)
feature_names = [f"Feature_{i}" for i in range(93)]

def ShowFS(X_res, y_res, k_optimal):
    selector = SelectKBest(score_func=f_classif, k=k_optimal)
    selector.fit(X_res, y_res)

    scores = selector.scores_
    selected_indices = selector.get_support(indices=True)

    selected_features_scores = [(feature_names[i], scores[i]) for i in selected_indices]
    selected_features_scores.sort(key=lambda x: x[1], reverse=True)

    df_anova = pd.DataFrame(selected_features_scores, columns=['Features', 'Scores'])
    return df_anova

# Getting the top features with their scores
k_optimal = 37  # You can set this to the desired number of top features
df_anova = ShowFS(X_res, y_res, k_optimal)
df_anova
# Out:
#       Features    Scores
# 0   Feature_75  6.989960
# 1   Feature_86  4.797635
# 2   Feature_51  4.693547
# 3   Feature_58  4.146929
# 4   Feature_32  3.258910
# 5   Feature_15  2.611849
# 6   Feature_60  2.525728
# 7   Feature_20  2.496952
# 8   Feature_24  2.434291
# 9   Feature_74  2.317460
# 10  Feature_90  2.252241
# 11  Feature_37  2.112720
# 12  Feature_50  2.027083
# 13  Feature_42  1.934618
# 14  Feature_68  1.872991
# 15  Feature_11  1.748636
# 16  Feature_28  1.681183
# 17  Feature_13  1.647748
# 18  Feature_45  1.633050
# 19  Feature_65  1.556836
# 20  Feature_16  1.517934
# 21  Feature_26  1.418654
# 22  Feature_73  1.303556
# 23  Feature_25  1.196676
# 24  Feature_83  1.087771
# 25  Feature_35  1.024931
# 26  Feature_78  0.885866
# 27  Feature_80  0.773030
# 28  Feature_19  0.766891
# 29  Feature_64  0.734905
# 30  Feature_49  0.655302
# 31  Feature_71  0.612134
# 32  Feature_10  0.602487
# 33  Feature_12  0.593331
# 34  Feature_39  0.529401
# 35  Feature_54  0.529383
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.feature_selection import SelectKBest, f_classif

# Generating synthetic data for the example with 93 features
np.random.seed(42)
X_res = np.random.rand(100, 93)  # 100 samples, 93 features
y_res = np.random.randint(0, 2, 100)  # Binary target variable
X_test = np.random.rand(30, 93)  # 30 samples, 93 features
y_test = np.random.randint(0, 2, 30)  # Binary target variable

# Assume feature names are given as follows (for example purposes)
feature_names = [f"Feature_{i}" for i in range(93)]

def ShowFS(X_res, y_res, k_optimal):
    selector = SelectKBest(score_func=f_classif, k=k_optimal)
    selector.fit(X_res, y_res)

    scores = selector.scores_
    selected_indices = selector.get_support(indices=True)

    selected_features_scores = [(feature_names[i], scores[i]) for i in selected_indices]
    selected_features_scores.sort(key=lambda x: x[1], reverse=True)

    df_anova = pd.DataFrame(selected_features_scores, columns=['Features', 'Scores'])
    return df_anova

# Getting the top features with their scores
k_optimal = 37  # Set to the desired number of top features
df_anova = ShowFS(X_res, y_res, k_optimal)

# Selecting features based on ANOVA
X_train_selected = pd.DataFrame(X_res, columns=feature_names)[df_anova['Features']]
X_test_selected = pd.DataFrame(X_test, columns=feature_names)[df_anova['Features']]

# Function to train and evaluate models
def train_model(X_train, y_train, X_test, y_test):
    models = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "SVM": SVC(),
        "Decision Tree": DecisionTreeClassifier(),
        "Naive Bayes": GaussianNB(),
        "KNN": KNeighborsClassifier()
    }

    results = []

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        precision = precision_score(y_test, y_pred, average='macro')

        results.append({
            "Model": name,
            "Accuracy": accuracy,
            "F-1": f1,
            "Recall": recall,
            "Precision": precision
        })

    df_results = pd.DataFrame(results)
    return df_results

# Training models and getting results
model_anova = train_model(X_train_selected, y_res, X_test_selected, y_test)
print(model_anova)
# Out:
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.533333  0.533333  0.542986   0.542986
# 1                  SVM  0.533333  0.531250  0.552036   0.555024
# 2        Decision Tree  0.500000  0.499444  0.504525   0.504464
# 3          Naive Bayes  0.600000  0.598214  0.619910   0.626794
# 4                  KNN  0.466667  0.466667  0.475113   0.475113

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.feature_selection import SelectKBest, f_classif

# Generating synthetic data for the example with 93 features
np.random.seed(42)
X_res = np.random.rand(100, 93)  # 100 samples, 93 features
y_res = np.random.randint(0, 2, 100)  # Binary target variable
X_test = np.random.rand(30, 93)  # 30 samples, 93 features
y_test = np.random.randint(0, 2, 30)  # Binary target variable

# Assume feature names are given as follows (for example purposes)
feature_names = [f"Feature_{i}" for i in range(93)]

def ShowFS(X_res, y_res, k_optimal):
    selector = SelectKBest(score_func=f_classif, k=k_optimal)
    selector.fit(X_res, y_res)

    scores = selector.scores_
    selected_indices = selector.get_support(indices=True)

    selected_features_scores = [(feature_names[i], scores[i]) for i in selected_indices]
    selected_features_scores.sort(key=lambda x: x[1], reverse=True)

    df_anova = pd.DataFrame(selected_features_scores, columns=['Features', 'Scores'])
    return df_anova

# Getting the top features with their scores
k_optimal = 37  # Set to the desired number of top features
df_anova = ShowFS(X_res, y_res, k_optimal)

# Selecting features based on ANOVA
X_train_selected = pd.DataFrame(X_res, columns=feature_names)[df_anova['Features']]
X_test_selected = pd.DataFrame(X_test, columns=feature_names)[df_anova['Features']]

# Function to train and evaluate models
def train_model(X_train, y_train, X_test, y_test):
    models = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "SVM": SVC(),
        "Decision Tree": DecisionTreeClassifier(),
        "Naive Bayes": GaussianNB(),
        "KNN": KNeighborsClassifier()
    }

    results = []

    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred, average='macro')
        recall = recall_score(y_test, y_pred, average='macro')
        precision = precision_score(y_test, y_pred, average='macro')

        results.append({
            "Model": name,
            "Accuracy": accuracy,
            "F-1": f1,
            "Recall": recall,
            "Precision": precision
        })

    df_results = pd.DataFrame(results)
    return df_results

# Training models and getting results
model_anova = train_model(X_train_selected, y_res, X_test_selected, y_test)

# Assuming `baseline` dataframe is given (Example: Random scores)
# Generate a dummy baseline for demonstration purposes
baseline = pd.DataFrame({
    "Model": ["Logistic Regression", "SVM", "Decision Tree", "Naive Bayes", "KNN"],
    "F-1": np.random.rand(5)  # Replace with actual baseline F1 scores
})

# Calculate the difference in F1 scores
selisih = model_anova['F-1'] - baseline['F-1']
print("Rerata peningkatan nilai F1 (Sebelum FS dan setelah FS): ", selisih.mean() * 100, "%")
# Out:
# Rerata peningkatan nilai F1 (Sebelum FS dan setelah FS):  32.30223161150137 %

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

# Generating synthetic data for the example
np.random.seed(42)
X_train_standard = np.random.rand(100, 93)  # Standard scaled training data
X_val_standard = np.random.rand(30, 93)  # Standard scaled validation data
y_res = np.random.randint(0, 2, 100)  # Binary target variable for training
y_val = np.random.randint(0, 2, 30)  # Binary target variable for validation

def score_per_k(X_train, y_train, X_val, y_val, max_k=92):
    scores = []
    for k in range(1, max_k + 1):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_val)
        f1 = f1_score(y_val, y_pred, average='macro')
        scores.append((k, f1))

    df_k = pd.DataFrame(scores, columns=['K', 'Mean F1 Scores'])
    return df_k

# Getting the score per k with F1 scores
df_k_standard = score_per_k(X_train_standard, y_res, X_val_standard, y_val)
print(df_k_standard)
# Out:
#      K  Mean F1 Scores
# 0    1        0.499444
# 1    2        0.457014
# 2    3        0.494949
# 3    4        0.457014
# 4    5        0.360269
# ..  ..             ...
# 87  88        0.302326
# 88  89        0.302326
# 89  90        0.302326
# 90  91        0.302326
# 91  92        0.302326
#
# [92 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

# Generating synthetic data for the example
np.random.seed(42)
X_train_standard = np.random.rand(100, 93)  # Standard scaled training data
X_val_standard = np.random.rand(30, 93)  # Standard scaled validation data
y_res = np.random.randint(0, 2, 100)  # Binary target variable for training
y_val = np.random.randint(0, 2, 30)  # Binary target variable for validation

def score_per_k(X_train, y_train, X_val, y_val, max_k=92):
    scores = []
    for k in range(1, max_k + 1):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(X_train, y_train)
        y_pred = knn.predict(X_val)
        f1 = f1_score(y_val, y_pred, average='macro')
        scores.append((k, f1))

    df_k = pd.DataFrame(scores, columns=['K', 'Mean F1 Scores'])
    return df_k

def select_k(df_k):
    k_optimal = df_k.loc[df_k['Mean F1 Scores'].idxmax()]['K']
    return int(k_optimal)

# Getting the score per k with F1 scores
df_k_standard = score_per_k(X_train_standard, y_res, X_val_standard, y_val)

# Selecting the optimal k
k_optimal_standard = select_k(df_k_standard)
print("Banyak fitur optimal untuk diambil:", k_optimal_standard)
# Out:
# Banyak fitur optimal untuk diambil: 12

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, f_classif

# Generating synthetic data for the example with 93 features
np.random.seed(42)
X_train_minmax = np.random.rand(100, 93)  # MinMax scaled training data
y_res = np.random.randint(0, 2, 100)  # Binary target variable

# Assume feature names are given as follows (for example purposes)
feature_names = [f"Feature_{i}" for i in range(93)]

def ShowFS(X, y, k):
    selector = SelectKBest(score_func=f_classif, k=k)
    selector.fit(X, y)

    scores = selector.scores_
    selected_indices = selector.get_support(indices=True)

    selected_features_scores = [(feature_names[i], scores[i]) for i in selected_indices]
    selected_features_scores.sort(key=lambda x: x[1], reverse=True)

    df_anova = pd.DataFrame(selected_features_scores, columns=['Features', 'Scores'])
    return df_anova

# Assume k_optimal_minmax is defined based on previous calculations
k_optimal_minmax = 37  # Example value, set to the desired number of top features

# Getting the top features with their scores
df_anova_minmax = ShowFS(X_train_minmax, y_res, k_optimal_minmax)
print(df_anova_minmax)
# Out:
#       Features    Scores
# 0   Feature_75  6.989960
# 1   Feature_86  4.797635
# 2   Feature_51  4.693547
# 3   Feature_58  4.146929
# 4   Feature_32  3.258910
# 5   Feature_15  2.611849
# 6   Feature_60  2.525728
# 7   Feature_20  2.496952
# 8   Feature_24  2.434291
# 9   Feature_74  2.317460
# 10  Feature_90  2.252241
# 11  Feature_37  2.112720
# 12  Feature_50  2.027083
# 13  Feature_42  1.934618
# 14  Feature_68  1.872991
# 15  Feature_11  1.748636
# 16  Feature_28  1.681183
# 17  Feature_13  1.647748
# 18  Feature_45  1.633050
# 19  Feature_65  1.556836
# 20  Feature_16  1.517934
# 21  Feature_26  1.418654
# 22  Feature_73  1.303556
# 23  Feature_25  1.196676
# 24  Feature_83  1.087771
# 25  Feature_35  1.024931
# 26  Feature_78  0.885866
# 27  Feature_80  0.773030
# 28  Feature_19  0.766891
# 29  Feature_64  0.734905
# 30  Feature_49  0.655302
# 31  Feature_71  0.612134
# 32  Feature_10  0.602487
# 33  Feature_12  0.593331
# 34  Feature_39  0.529401
# 35  Feature_54  0.529383
# ...

# %%
print("Fitur yang diambil: ", k_optimal)
model_anova
# Out:
# Fitur yang diambil:  37
#                  Model  Accuracy       F-1    Recall  Precision
# 0  Logistic Regression  0.533333  0.533333  0.542986   0.542986
# 1                  SVM  0.533333  0.531250  0.552036   0.555024
# 2        Decision Tree  0.500000  0.499444  0.504525   0.504464
# 3          Naive Bayes  0.600000  0.598214  0.619910   0.626794
# 4                  KNN  0.466667  0.466667  0.475113   0.475113

# %%
class PCAScratch():
    def __init__(self, n_components):
        self.n_components = n_components
        self.components_ = None
        self.mean_ = None
        self.feature_names_ = None

    def fit(self, X):
        self.mean_ = X.mean()
        X_centered = X - self.mean_

        cov_matrix = np.cov(X_centered.values, rowvar=False)

        eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

        sorted_indices = np.argsort(eigenvalues)[::-1]
        sorted_eigenvalues = eigenvalues[sorted_indices]
        sorted_eigenvectors = eigenvectors[:, sorted_indices]

        self.components_ = sorted_eigenvectors[:, :self.n_components]
        return self.components_

    def transform(self, X):
        X_centered = X - self.mean_

        transformed_data = np.dot(X_centered.values, self.components_)

        return transformed_data

# %%
def ShowPCA (trainX, valX, k):
    pca = PCAScratch(k)
    pca.fit(trainX)

    trainX_pca = pca.transform(trainX)
    valX_pca = pca.transform(valX)

    return trainX_pca, valX_pca

# %%
def score_per_k_pca (trainX, trainY, valX, valY):
    num_k = []
    scores = []

    for i in range(1, len(trainX.columns)):
        num_k.append(i)

        X_train_pca, X_val_pca = ShowPCA(trainX, valX, i)

        df_train = train_model(X_train_pca, trainY, X_val_pca, valY)
        scores.append(df_train['F-1'].mean())

    df_k = pd.DataFrame({'K':num_k, 'Mean F1 Scores':scores})
    return df_k

# %%
def select_k_pca (df_k):
    max_f1_score = df_k['Mean F1 Scores'].idxmax()
    k_optimal = df_k.loc[max_f1_score, 'K']
    return k_optimal

# %%
baseline
# Out:
#                  Model       F-1
# 0  Logistic Regression  0.013660
# 1                  SVM  0.077648
# 2        Decision Tree  0.391695
# 3          Naive Bayes  0.153974
# 4                  KNN  0.376820
